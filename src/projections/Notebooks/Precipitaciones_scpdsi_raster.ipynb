# %%
import pandas as pd
import numpy as np
import yaml
from tqdm import tqdm
from pathlib import Path
from glob import glob
from functools import partial
from multiprocessing import Pool

import shapefile
import shapely
from shapely.geometry import Point

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from projections.shapefiles import load_shapes_by_country
from projections.models import Records
from projections import raster, utils

pd.set_option('max_columns', None)

# %%
output_folder = Path('../Output/Precipitaciones/Raster/SCPDSI/')

# %%
df = pd.read_csv('../Data/Precipitaciones/scpdsi_80-20.csv')
print(df.shape)
print('Unique locs', df.drop_duplicates(['lon', 'lat']).shape)
df.head()
# Out:
# (64040, 494)
# Unique locs (64040, 494)
#      lon    lat  80-01  80-02  80-03  80-04  80-05  80-06  80-07  80-08  \
# 0 -72.25  83.25  -0.46  -0.39  -0.34  -0.34  -0.99  -1.07  -1.41   2.14
# 1 -71.75  83.25  -0.40  -0.32  -0.27  -0.09  -0.70  -0.88  -1.26   1.83
# 2 -70.75  83.25  -0.42  -0.34  -0.31  -0.25  -0.37  -0.77  -1.01   2.60
# 3 -70.25  83.25  -0.40  -0.35  -0.30  -0.31  -0.45  -0.90  -1.15   2.45
# 4 -69.75  83.25  -0.41  -0.34  -0.28  -0.29  -0.13  -0.81  -1.13   2.02
#
#    80-09  80-10  80-11  80-12  81-01  81-02  81-03  81-04  81-05  81-06  \
# 0   4.22   3.89   3.35   2.89   2.49   2.14   1.85   1.58   2.06   2.86
# 1   4.06   3.59   2.85   2.33   1.91   1.56   1.28   0.96   1.53   1.60
# 2   4.10   3.72   3.16   2.79   2.60   2.22   1.83   1.45   1.34   1.30
# 3   4.20   3.83   3.28   2.85   2.67   2.32   2.01   1.76   1.62   1.98
# 4   4.53   4.01   3.24   2.68   2.21   1.82   1.50   1.27   1.07   1.25
#
# ...

# %% [markdown]
# # ADM

# %%
cru = pd.read_csv(output_folder / '../CRU/loc_map.csv')
cru.head()
# Out:
#    index    lat    lon adm0     adm1       adm2  intersection_ratio
# 0  14876   4.25  73.25  MDV      NaN        NaN            0.000956
# 1  14877   4.25  73.75  MDV      NaN        NaN            0.003977
# 2  29703  34.25  35.75  LBN  LBN.1_1  LBN.1.1_1            0.003222
# 3  29704  34.25  36.25  LBN  LBN.1_1  LBN.1.1_1            0.072300
# 4  29704  34.25  36.25  LBN  LBN.2_1  LBN.2.1_1            0.544474

# %%
# CRU and SCPDSI share the same locations
df = df.merge(cru, on=['lon', 'lat'])
print(df.shape)
df.head()
# Out:
# 0
#      lon    lat  80-01  80-02  80-03  80-04  80-05  80-06  80-07  80-08  \
# 0 -38.25  83.25   1.68   1.81  -0.19  -0.17  -0.14  -0.84  -0.85   1.55
# 1 -37.75  83.25   0.00   0.00  -0.12  -0.12  -0.11  -0.78  -0.77   2.16
# 2 -36.75  83.25   0.00   0.00  -0.08   0.09   0.00  -0.89  -0.94   2.13
# 3 -36.25  83.25   3.50   3.70   3.21   3.08   2.77   1.63   1.27   3.17
# 4 -35.75  83.25   2.37   2.86   2.33   2.57   2.21   0.80   0.45   2.99
#
#    80-09  80-10  80-11  80-12  81-01  81-02  81-03  81-04  81-05  81-06  \
# 0  -0.19  -0.16   0.11   0.00   0.00  -0.12  -0.56  -0.63  -0.54  -1.03
# 1  -0.53  -0.46  -0.23  -0.20  -0.18  -0.16  -0.50  -0.46  -0.40  -0.85
# 2  -0.54  -0.48  -0.25  -0.22  -0.20  -0.18  -0.55  -0.55  -0.49  -0.72
# 3  -0.39  -0.35  -0.19  -0.17  -0.16  -0.31  -0.81  -1.04  -0.94  -1.25
# 4  -0.46  -0.40  -0.39  -0.34  -0.33  -0.60  -1.25  -1.58  -1.53  -1.56
#
#    81-07  81-08  81-09  81-10  81-11  81-12  82-01  82-02  82-03  82-04  \
# ...

# %%
# The score of an adm2 is the average of all measures weighted by intersection_ratio
value_cols = list(df.filter(regex=r'^\d\d-\d\d$').columns)
df[value_cols] *= df[value_cols].multiply(df['intersection_ratio'], axis=0)

id_vars = ['adm0', 'adm1', 'adm2']

aggfunc = {col: 'mean' for col in value_cols}
aggfunc['intersection_ratio'] = [np.sum, 'count']

pivot = pd.pivot_table(
    df,
    index=id_vars,
    values=value_cols + ['intersection_ratio'],
    aggfunc=aggfunc
)

pivot.columns = ['_'.join(x) if x[0] == 'intersection_ratio' else x[0] for x in pivot.columns]

pivot[value_cols] = pivot[value_cols].divide(pivot['intersection_ratio_sum'], axis=0)

# Reshape to long
melt = pivot.reset_index().melt(
    id_vars=id_vars,
    value_vars=value_cols,
    var_name='time',
    value_name='precipitation'
)

melt = melt.merge(
    pivot[['intersection_ratio_count', 'intersection_ratio_sum']],
    left_on=id_vars,
    right_index=True
)

# Fix year mapping
year_map = {}
month_map = {}
for t in value_cols:
    year, month = t.split('-')
    year = int(year)
    year = 1900 + year if year > 20 else 2000 + year
    year_map[t] = year
    month_map[t] = int(month)
    
melt['year'] = melt['time'].map(year_map)
melt['month'] = melt['time'].map(month_map)
melt.drop(columns='time', inplace=True)

# Save results
melt.to_csv(output_folder / f'{output_folder.name}.csv', index=False)
print(melt.shape)
melt.head()
# Out:
# (10479600, 8)
#       adm0      adm1        adm2  precipitation  intersection_ratio_count  \
# 0      AFG  AFG.10_1  AFG.10.1_1       0.387072                         9
# 21300  AFG  AFG.10_1  AFG.10.1_1       0.812244                         9
# 42600  AFG  AFG.10_1  AFG.10.1_1       1.340727                         9
# 63900  AFG  AFG.10_1  AFG.10.1_1       1.000916                         9
# 85200  AFG  AFG.10_1  AFG.10.1_1       0.746590                         9
#
#        intersection_ratio_sum  year  month
# 0                    4.110212  1980      1
# 21300                4.110212  1980      2
# 42600                4.110212  1980      3
# 63900                4.110212  1980      4
# 85200                4.110212  1980      5

# %% [markdown]
# # Aggregate

# %%
df = pd.read_csv(output_folder / f'{output_folder.name}.csv')

time_groups = {'yearly': ['year'], 'monthly': ['year', 'month']}
loc_groups = {'country': ['adm0'], 
              'edo': ['adm0', 'adm1'], 
              'mun': ['adm0', 'adm1', 'adm2']}

groups = {}
for loc_name, loc_group in loc_groups.items():
    for time_name, time_group in time_groups.items():
        groups[f'{loc_name}_{time_name}'] = loc_group + time_group

done = [Path(x).name for x in glob(str(output_folder / 'CRU_*.csv'))]
    
for group_name, group in groups.items():
    fname = f'{output_folder.name}_{group_name}.csv'
    if fname in done:
        continue

    print(group_name)
    collapsed = []

    pivot = pd.pivot_table(df, 
                           values=['precipitation'],
                           index=group,
                           aggfunc=[np.mean, np.median, np.std, 'count'])
    pivot.columns = ['_'.join(x) for x in pivot.columns]
    pivot.to_csv(output_folder / fname)
# Out:
# country_yearly
# country_monthly
# edo_yearly
# edo_monthly
# mun_yearly
# mun_monthly

# %% [markdown]
# # Ethnic

# %%
cru = pd.read_csv(output_folder / '../CRU/ethnic_map.csv')
print(df.shape)
df = df.merge(cru, on=['lon', 'lat'])
print(df.shape)
df.head()
# Out:
# (64040, 494)
# (11386, 498)
#      lon    lat  80-01  80-02  80-03  80-04  80-05  80-06  80-07  80-08  \
# 0   8.75  37.25  -1.31  -1.74  -1.45  -1.10  -0.79  -0.99  -1.24  -1.34
# 1   9.25  37.25  -1.00  -1.45  -1.16  -0.87  -0.77  -1.12  -1.26  -1.28
# 2   9.75  37.25  -1.09  -1.57  -1.34  -1.16  -1.04  -1.24  -1.26  -1.29
# 3  10.25  37.25  -1.63  -1.92  -1.70  -1.52  -1.56  -1.76  -1.80  -1.78
# 4   8.25  36.75  -1.33  -1.90  -1.70  -1.48  -1.33  -1.86  -2.07  -2.11
#
#    80-09  80-10  80-11  80-12  81-01  81-02  81-03  81-04  81-05  81-06  \
# 0  -1.72  -1.66   0.12   0.64   0.75  -0.05  -0.35  -0.52  -0.64  -0.59
# 1  -1.66  -1.67  -1.52  -0.95  -0.72  -0.81  -1.04  -1.22  -1.27  -1.15
# 2  -1.76  -1.79  -1.64  -1.10  -0.88  -0.96  -1.14  -1.28  -1.38  -1.24
# 3  -2.04  -2.08  -2.08  -1.78  -1.67  -1.63  -1.79  -1.96  -2.01  -1.99
# 4  -2.26  -2.22   0.14   0.66   0.77   0.72  -0.26  -0.26  -0.37  -0.27
#
# ...

# %%
pivot = raster.weighted_pivot(
    df, 
    weight='intersection_ratio', 
    value_name='precipitation', 
    id_vars=['NAME', 'TRIBE_CODE', 'GID_0']
)
utils.map_year_month(pivot, 'time', 1980, 2020)

# Save results
pivot.to_csv(output_folder / 'SCPDSI.csv', index=False)
print(pivot.shape)
pivot.head()
# Out:
# (481668, 9)
#         NAME  TRIBE_CODE GID_0   time  precipitation  \
# 0     ABABDA           1   EGY  80-01       0.171013
# 979   ABABDA           1   EGY  80-02       0.178830
# 1958  ABABDA           1   EGY  80-03       0.261796
# 2937  ABABDA           1   EGY  80-04       0.441934
# 3916  ABABDA           1   EGY  80-05       0.557372
#
#       intersection_ratio_count  intersection_ratio_sum  year  month
# 0                           12                9.912794  1980      1
# 979                         12                9.912794  1980      2
# 1958                        12                9.912794  1980      3
# 2937                        12                9.912794  1980      4
# 3916                        12                9.912794  1980      5

# %%
# Aggregate
time_groups = {'yearly': ['year'], 'monthly': ['year', 'month']}
loc_groups = {'ethnic': ['NAME', 'TRIBE_CODE', 'GID_0']}

groups = {}
for loc_name, loc_group in loc_groups.items():
    for time_name, time_group in time_groups.items():
        groups[f'{loc_name}_{time_name}'] = loc_group + time_group

output_folder = Path('../Output/Precipitaciones/Raster/SCPDSI_Ethnic/')
output_folder.mkdir(exist_ok=True)
done = [Path(x).name for x in glob(str(output_folder / 'SCPDSI_*.csv'))]
    
utils.aggregate_by_groups(pivot, groups, output_folder, ['precipitation'], done=done, batch=None)
# Out:
# Aggregating: 100%|██████████| 2/2 [00:05<00:00,  2.82s/it]
