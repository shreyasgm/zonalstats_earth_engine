# %%
import pandas as pd
import numpy as np

from gensim.utils import deaccent

# %%
codes = pd.read_excel('../Data/ven_codes.xls', sheet_name='adm2')
codes.columns = [x.lower() for x in codes.columns]
for col in ['estado', 'municipio']:
    codes[col] = codes[col].str.lower().apply(deaccent)
    
codes['estado'] = codes['estado'].str.replace(r'^distrito federal$', 'distrito capital')

# %%
adm = pd.read_csv('../Data/GADM_codes.csv')
adm.columns = [x.lower() for x in adm.columns]
adm = adm.loc[np.logical_and(adm['adm0'] == 'VEN', adm['adm2'].notnull()),
              ['adm1_name', 'adm2_name', 'adm1', 'adm2']].copy()

# %%
for col in ['adm1_name', 'adm2_name']:
    adm[col] = adm[col].str.lower().apply(deaccent)
    
adm = adm[adm['adm1_name'] != 'dependencias federales'].copy()

# %%
assert len(set(adm['adm1_name'].unique()).symmetric_difference(codes['estado'].unique())) == 0

# %%
adm = adm.merge(codes, 
                left_on=['adm1_name', 'adm2_name'], 
                right_on=['estado', 'municipio'], 
                how='outer', 
                indicator=True)
print((adm['_merge'] == 'left_only').sum(), (adm['_merge'] == 'right_only').sum())
# Out:
# 64 62

# %%
adm['adm1_name'].fillna(adm['estado'], inplace=True)
adm['estado'].fillna(adm['adm1_name'], inplace=True)
assert adm['adm1_name'].isnull().sum() == 0
assert adm['estado'].isnull().sum() == 0

# %%
def either_contains(s1, s2):
    return s1 in s2 or s2 in s1

# %%
for adm_idx, adm_mun in adm[adm['_merge'] == 'left_only'].iterrows():
    mask = np.logical_and(
        adm['_merge'] == 'right_only',
        adm['estado'] == adm_mun['adm1_name'],
    )
    for code_idx, code_mun in adm[mask].iterrows():
        if either_contains(adm_mun['adm2_name'], code_mun['municipio']):
            adm.loc[adm_idx, 'municipio'] = code_mun['municipio']
            adm.loc[adm_idx, 'code'] = code_mun['code']
            
            adm.loc[code_idx, 'adm2_name'] = adm_mun['adm2_name']
            adm.loc[code_idx, 'adm1'] = adm_mun['adm1']
            adm.loc[code_idx, 'adm2'] = adm_mun['adm2']
            
            break
            
print(adm['adm2_name'].isnull().sum(), adm['municipio'].isnull().sum())
# Out:
# 19 21

# %%
adm.to_csv('../Output/ve_crosswalk.csv', index=False)

# %%
adm[adm['adm2_name'].isnull()]
# Out:
#          adm1_name adm2_name adm1 adm2         estado           municipio  \
# 345     anzoategui       NaN  NaN  NaN     anzoategui  francisco del carm
# 346     anzoategui       NaN  NaN  NaN     anzoategui  francisco de miran
# 347     anzoategui       NaN  NaN  NaN     anzoategui  juan antonio sotil
# 348     anzoategui       NaN  NaN  NaN     anzoategui  juan manuel cajiga
# 349     anzoategui       NaN  NaN  NaN     anzoategui  jose gregorio mona
# 350     anzoategui       NaN  NaN  NaN     anzoategui  manuel ezequiel br
# 351     anzoategui       NaN  NaN  NaN     anzoategui  pedro maria freite
# 352     anzoategui       NaN  NaN  NaN     anzoategui  san jose de guanip
# 355     anzoategui       NaN  NaN  NaN     anzoategui  sir artur mc grego
# 357         aragua       NaN  NaN  NaN         aragua  jose rafael reveng
# 362        bolivar       NaN  NaN  NaN        bolivar          raul leoni
# 363       carabobo       NaN  NaN  NaN       carabobo       carlos arvelo
# 365        cojedes       NaN  NaN  NaN        cojedes          san carlos
# 366         falcon       NaN  NaN  NaN         falcon          los taques
# 367         falcon       NaN  NaN  NaN         falcon           palmasola
# 371        guarico       NaN  NaN  NaN        guarico  francisco de miran
# 373        guarico       NaN  NaN  NaN        guarico    jose felix rivas
# 382  nueva esparta       NaN  NaN  NaN  nueva esparta            villalba
# 398          zulia       NaN  NaN  NaN          zulia                paez
#
#        code      _merge
# 345  VE0304  right_only
# 346  VE0305  right_only
# 347  VE0308  right_only
# 348  VE0309  right_only
# 349  VE0310  right_only
# 350  VE0312  right_only
# 351  VE0313  right_only
# 352  VE0315  right_only
# 355  VE0320  right_only
# 357  VE0506  right_only
# 362  VE0707  right_only
# 363  VE0802  right_only
# 365  VE0908  right_only
# 366  VE1112  right_only
# 367  VE1116  right_only
# 371  VE1208  right_only
# 373  VE1211  right_only
# 382  VE1711  right_only
# 398  VE2315  right_only
